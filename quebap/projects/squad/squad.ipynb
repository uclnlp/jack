# %%
# %load_ext autoreload
# %autoreload 2
# %matplotlib inline

# %%
import quebap.read_quebap
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# <ipython-input-2-fc7dfa632403> in <module>()
# ----> 1 import quebap.quebap.read_quebap
#
# ImportError: No module named 'quebap'
